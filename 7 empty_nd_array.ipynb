# %%
# .empty function


import numpy as np

arr_empty=np.empty(4)
print(arr_empty)         #we get random value or the value that is already in that memory.

print(type(arr_empty))
print(arr_empty.ndim)
# Out:
# [2.16851034e+243 4.27242994e+180 3.65588327e+233 1.97498397e+166]
# <class 'numpy.ndarray'>
# 1

# %%
#explicitely passing rows and columns

array_empty=np.empty((3,4))   # 3 rows and 4 columns with random values

print(array_empty)
print(f"the dimension of the empty array is {array_empty.ndim}")
# Out:
# [[6.95214513e-310 5.13241968e-305 0.00000000e+000 1.26166557e-311]
#  [1.21190256e-305 0.00000000e+000 1.26166483e-311 2.00485144e-307]
#  [0.00000000e+000 1.26166484e-311 7.56745120e-307 0.00000000e+000]]
# the dimension of the empty array is 2

# %%
array=np.ones(3,4)
print(array)
print(array.ndim)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 array=np.ones(3,4)
#       2 print(array)
#       3 print(array.ndim)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\numeric.py:233, in ones(shape, dtype, order, device, like)
#     228 if like is not None:
#     229     return _ones_with_like(
#     230         like, shape, dtype=dtype, order=order, device=device
#     231     )
# --> 233 a = empty(shape, dtype, order, device=device)
#     234 multiarray.copyto(a, 1, casting='unsafe')
#     235 return a
#
# TypeError: Cannot interpret '4' as a data type
