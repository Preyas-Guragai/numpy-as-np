# %% [markdown]
# #RANDINT(); generates random value in the given range
# in rand(), randn(), ranf(), the range is used to be [0,1)

# %%
import numpy as np

#var=np.random.randint(min_value, max_value, total_value)
