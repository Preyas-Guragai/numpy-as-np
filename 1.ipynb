# %%
#see time required to run

import numpy as np
# %time np.arange(1,5)**3  #time  taken to run single line code time
# Out:
# CPU times: total: 0 ns
# Wall time: 61.5 μs
# array([ 1,  8, 27, 64])

# %%
# %%timeit  #gives overall time taken to execute
total = 0
for i in range(1000):
    total += i
# Out:
# The slowest run took 4.39 times longer than the fastest. This could mean that an intermediate result is being cached.
# 126 μs ± 78.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
