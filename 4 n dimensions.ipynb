# %%
# CREATING N-DIMENSION ARRAY. 
#IF YOU WANT TO CREATE, LETS SAY 10-D ARRAY. IT IS NOT NECESSARY TO PUT 10 BRACKETS.
#YOU CAN USE "ndmin"

import numpy as np
nd_array=np.array([1,2,3,4,5], ndmin=10) #ndmin creates the no of dimension
print(nd_array)
print(nd_array.ndim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # CREATING N-DIMENSION ARRAY.
#       2 #IF YOU WANT TO CREATE, LETS SAY 10-D ARRAY. IT IS NOT NECESSARY TO PUT 10 BRACKETS.
#       3 #YOU CAN USE "ndmin"
# ----> 5 nd_array=np.array([1,2,3,4,5], ndmin=10) #ndmin creates the no of dimension
#       6 print(nd_array)
#       7 print(nd_array.ndim)
#
# NameError: name 'np' is not defined
